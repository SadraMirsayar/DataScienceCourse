# %%
import pandas as pd

# %%
data = DataFrame = pd.read_csv('flights.csv')
data.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
data['arr_delay'].mean()

# import numpy as np
# np.mean(data['arr_delay'])
# Out:
# 6.89537675731489

# %%
data['arr_delay']
# Out:
# 0         11.0
# 1         20.0
# 2         33.0
# 3        -18.0
# 4        -25.0
#           ...
# 336771     NaN
# 336772     NaN
# 336773     NaN
# 336774     NaN
# 336775     NaN
# Name: arr_delay, Length: 336776, dtype: float64

# %%
# Trimmed Mean
# https://pub.towardsai.net/descriptive-statistics-with-pandas-a1e206287199

from scipy import stats
stats.trim_mean(data['arr_delay'], 0.1)
# Out:
# 0.9612355338465307

# %%
data['arr_delay'].median()
# Out:
# -5.0

# %%
data['arr_delay'].mode()
# Out:
# 0   -13.0
# Name: arr_delay, dtype: float64

# %%
data['arr_delay'].std()
# Out:
# 44.63329169019399

# %%
data['arr_delay'].hist(bins=200)
# Out:
# <Axes: >

# %%
data['arr_delay']
# Out:
# 0         11.0
# 1         20.0
# 2         33.0
# 3        -18.0
# 4        -25.0
#           ...
# 336771     NaN
# 336772     NaN
# 336773     NaN
# 336774     NaN
# 336775     NaN
# Name: arr_delay, Length: 336776, dtype: float64

# %%
[data['arr_delay'] < 100]
# Out:
# [0          True
#  1          True
#  2          True
#  3          True
#  4          True
#            ...
#  336771    False
#  336772    False
#  336773    False
#  336774    False
#  336775    False
#  Name: arr_delay, Length: 336776, dtype: bool]

# %%
data['arr_delay'][data['arr_delay'] < 100]
# Out:
# 0         11.0
# 1         20.0
# 2         33.0
# 3        -18.0
# 4        -25.0
#           ...
# 336765   -17.0
# 336766   -20.0
# 336767   -16.0
# 336768     1.0
# 336769   -25.0
# Name: arr_delay, Length: 313187, dtype: float64

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=80)
# Out:
# <Axes: >

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=200)
# Out:
# <Axes: >

# %%
data['arr_delay'][data['arr_delay'] < 100].hist(bins=20)
# Out:
# <Axes: >

# %%
data['arr_delay'].std()
# Out:
# 44.63329169019399

# %%
data['arr_delay'].mean() - (3 * data['arr_delay'].std())
# Out:
# -127.00449831326708

# %%
data['arr_delay'].mean() + (3 * data['arr_delay'].std())
# Out:
# 140.79525182789686

# %%
data['arr_delay'].skew()
# Out:
# 3.7168174804571863

# %%
data['arr_delay'].kurtosis()
# Out:
# 29.233043998766775

# %%
# data.corr(method='pearson', numeric_only='True')
data.corr(numeric_only='True')
# Out:
#                       id  year     month       day  dep_time  sched_dep_time  \
# id              1.000000   NaN  0.071779  0.087852  0.002172        0.004076
# year                 NaN   NaN       NaN       NaN       NaN             NaN
# month           0.071779   NaN  1.000000  0.002942 -0.003932       -0.004573
# day             0.087852   NaN  0.002942  1.000000 -0.000467       -0.000014
# dep_time        0.002172   NaN -0.003932 -0.000467  1.000000        0.954617
# sched_dep_time  0.004076   NaN -0.004573 -0.000014  0.954617        1.000000
# dep_delay       0.049713   NaN -0.020057  0.000420  0.260231        0.198887
# arr_time       -0.024680   NaN -0.002520 -0.005537  0.660779        0.642680
# sched_arr_time -0.013373   NaN -0.004173 -0.002403  0.784682        0.783342
# arr_delay       0.018613   NaN -0.017382 -0.000319  0.232306        0.173896
# flight          0.002676   NaN -0.000834 -0.001791  0.041957        0.036495
# ...

# %%
data.corr(method='spearman', numeric_only='True')
# Out:
#                       id  year     month       day  dep_time  sched_dep_time  \
# id              1.000000   NaN  0.068423  0.087983  0.002409        0.004131
# year                 NaN   NaN       NaN       NaN       NaN             NaN
# month           0.068423   NaN  1.000000  0.002923 -0.004394       -0.004647
# day             0.087983   NaN  0.002923  1.000000 -0.000463       -0.000080
# dep_time        0.002409   NaN -0.004394 -0.000463  1.000000        0.971714
# sched_dep_time  0.004131   NaN -0.004647 -0.000080  0.971714        1.000000
# dep_delay       0.039394   NaN -0.016497  0.006105  0.289806        0.232511
# arr_time       -0.021611   NaN -0.003759 -0.004305  0.803024        0.785586
# sched_arr_time -0.011347   NaN -0.004762 -0.001632  0.877109        0.882137
# arr_delay      -0.037711   NaN -0.014652 -0.000133  0.205734        0.156957
# flight          0.004178   NaN  0.004478 -0.000430  0.034215        0.032365
# ...

# %%
data.corr(method='kendall', numeric_only='True')
# Out:
#                       id  year     month       day  dep_time  sched_dep_time  \
# id              1.000000   NaN  0.257181  0.085193  0.002578        0.003543
# year                 NaN   1.0       NaN       NaN       NaN             NaN
# month           0.257181   NaN  1.000000  0.002078 -0.002997       -0.003215
# day             0.085193   NaN  0.002078  1.000000 -0.000314       -0.000053
# dep_time        0.002578   NaN -0.002997 -0.000314  1.000000        0.934209
# sched_dep_time  0.003543   NaN -0.003215 -0.000053  0.934209        1.000000
# dep_delay       0.026839   NaN -0.011568  0.004218  0.202507        0.159839
# arr_time       -0.013646   NaN -0.002494 -0.002917  0.770480        0.742849
# sched_arr_time -0.006940   NaN -0.003247 -0.001106  0.802750        0.824497
# arr_delay      -0.024066   NaN -0.008979 -0.000121  0.139801        0.106096
# flight          0.002807   NaN  0.003208 -0.000293  0.023111        0.021949
# ...
